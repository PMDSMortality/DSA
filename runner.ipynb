# %%
import crawler as cr
import importlib
importlib.reload(cr)

#get crawled entries
result = cr.crawl_page_lazy_loading(save_as_file=True)
# Out:
# 50000
# 100000
# 150000
# 200000

# %%
len(result)
# Out:
# 785

# %%
extracted_elements = cr.extract_from_entries(result, "h3")
extracted_elements
# Out:
# ['14. Februar 2023',
#  '3. Februar 2023',
#  '2. Februar 2023',
#  '18. Januar 2023',
#  '24. November 2022',
#  '14. Oktober 2022',
#  '12. Oktober 2022',
#  '7. Oktober 2022',
#  '30. September 2022',
#  '23. September 2022',
#  '9. September 2022',
#  '08. September 2022',
#  '1. September 2022',
#  '26. August 2022',
#  '24. August 2022',
#  '12. August 2022',
#  'Virtuelle Statements der Minister zum Download',
#  '28. Juli 2022',
#  '29. Juni 2022',
#  'Neue Testverordnung gilt seit\xa0dem 30. Juni 2022',
#  '24. Juni 2022',
#  '23. Juni 2022',
#  '17. Juni 2022',
#  '7-Punkte-Plan für den Herbst',
#  '16. Juni 2022',
#  '20. Mai 2022',
#  '18. Mai 2022',
#  '2. Mai 2022',
#  '8. April 2022',
#  '6. April 2022',
#  '30. März 2022',
#  '29. März 2022',
#  '28. März 2022',
#  '25. März 2022',
#  '24. März 2022',
#  '18. März 2022',
#  '17. März 2022',
#  '11. März 2022',
#  '9. März 2022',
#  '4. März 2022',
#  '2. März 2022',
#  '25. Februar 2022',
#  '18. Februar 2022',
# ...
